# %%
# %load_ext autoreload
# %autoreload 2
import os 
os.chdir("/Users/luohy/Documents/Projects/bus-observatory/gtfs-realtime-performance")
from src.s3 import list_files_in_bucket, filter_files_by_pattern, read_parquet_from_s3
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed
from src.gtfs_segments import GTFS_shape_processor
from src.speeds import BusSpeedCalculator
from src.api import parse_zipped_gtfs
import geopandas as gpd
from src.api import query_feed_data, get_access_token
ACCESS_TOKEN = get_access_token()
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
from collections import defaultdict
from shapely.geometry import Point, Polygon
from datetime import datetime
import pytz
import contextily as ctx

# %%
def read_all_csv_files(file_list, dir) -> pd.DataFrame:
    """
    Given a list of file names, read all the csv files and return a concatenated dataframe.
    """
    dfs = []
    for file in file_list:
        dfs.append(pd.read_csv(os.path.join(dir, file)))
    return pd.concat(dfs, ignore_index=True)

# %%
def get_all_weekdays(start_date: str, end_date: str, weekday_type: int):
    # 0 - Monday, 1 - Tuesday, ..., 6 - Sunday
    # return a list of date strings
    dates = []
    date_range = pd.date_range(start=start_date, end=end_date, freq='D')
    for date in date_range:
        if date.weekday() == weekday_type:
            dates.append(date.strftime('%Y-%m-%d'))
    return dates

ans = get_all_weekdays("2025-01-01", "2025-01-31", 0) # get all mondays
print(ans)
# Out:
# ['2025-01-06', '2025-01-13', '2025-01-20', '2025-01-27']

# %% [markdown]
# # Use Case: Bus Speed Comparsion
#
# - Bus Route: M50
# - Date: Dec 2024 and Jan 2025

# %% [markdown]
# ## Data Loading and Transformation

# %%
route_id = "M50"
comparison_days = get_all_weekdays("2024-12-05", "2024-12-31", 2) # get all Wednesdays in Dec 2024
experiment_days = get_all_weekdays("2025-01-05", "2025-01-31", 2) # get all Wednesdays in Jan 2025

print(comparison_days)
print(experiment_days)
# Out:
# ['2024-12-11', '2024-12-18', '2024-12-25']
# ['2025-01-08', '2025-01-15', '2025-01-22', '2025-01-29']

# %%
# loading and concatenting all the files needed
comparison_files = [f"speeds_{route_id}_{date}.csv" for date in comparison_days]
experiment_files = [f"speeds_{route_id}_{date}.csv" for date in experiment_days]

# TODO: read csv files according to group of dates
bus_speed_comparison = read_all_csv_files(comparison_files, "data/2024-dec/")
bus_speed_experiment = read_all_csv_files(experiment_files, "data/2025-jan/")

# check the first row of the dataframe
print(bus_speed_comparison.iloc[0])
# Out:
# trip_id                                         MQ_O4-Weekday-030500_M50_351
# shape_id                                                             M500049
# stop_sequence                                                              3
# stop_id                                                               402185
# stop_name                                                       E 49 ST/3 AV
# prev_stop_id                                                          405193
# prev_stop_name                                                  E 49 ST/2 Av
# projected_position                                               1409.476125
# prev_projected_position                                           754.684091
# segment_length                                                    654.792033
# interpolated_time                                        2024-12-11 05:30:19
# time_elapsed                                                            14.0
# ...

# %% [markdown]
# ### Geographical Boundary Check

# %%
def fetch_all_static_feeds(mdb_id: str, ACCESS_TOKEN: str) -> pd.DataFrame:
    response = query_feed_data(mdb_id, ACCESS_TOKEN)
    if response is None:
        raise ValueError("No response for mdb_id: ", mdb_id)
    # Convert the response to a DataFrame
    feed_updates = pd.DataFrame(response)
    # For each row where service_date_range_start is null, fill it with downloaded_at date
    if "service_date_range_start" in feed_updates.columns:
        extracted_dates = feed_updates["downloaded_at"].str.extract(r"(\d{4}-\d{2}-\d{2})")[0]
        feed_updates["service_date_range_start"] = feed_updates["service_date_range_start"].fillna(extracted_dates)  
    
    return feed_updates   

mdb_id = "mdb-513"
feed_updates = fetch_all_static_feeds(mdb_id, ACCESS_TOKEN=ACCESS_TOKEN)
print(feed_updates)
# Out:
#                      id  feed_id  \
# 0  mdb-513-202402080022  mdb-513
# 1  mdb-513-202404010033  mdb-513
# 2  mdb-513-202407010038  mdb-513
# 3  mdb-513-202408290052  mdb-513
# 4  mdb-513-202409090026  mdb-513
# 5  mdb-513-202412120015  mdb-513
# 6  mdb-513-202501020055  mdb-513
# 7  mdb-513-202501230024  mdb-513
# 8  mdb-513-202502170105  mdb-513
#
#                                           hosted_url  note  \
# 0  https://files.mobilitydatabase.org/mdb-513/mdb...  None
# 1  https://files.mobilitydatabase.org/mdb-513/mdb...  None
# 2  https://files.mobilitydatabase.org/mdb-513/mdb...  None
# 3  https://files.mobilitydatabase.org/mdb-513/mdb...  None
# 4  https://files.mobilitydatabase.org/mdb-513/mdb...  None
# 5  https://files.mobilitydatabase.org/mdb-513/mdb...  None
# 6  https://files.mobilitydatabase.org/mdb-513/mdb...  None
# 7  https://files.mobilitydatabase.org/mdb-513/mdb...  None
# 8  https://files.mobilitydatabase.org/mdb-513/mdb...  None
#
# ...

# %%
# load the boundary shape file
boundary = gpd.read_file("data/congestion_zone_boundary.geojson")

# create stop points from feed:  url -> GTFS_dict -> stops.txt
def create_and_check_stop_points(feed_identifier, feed_updates, boundary_shape):
    # get GFTS dict from feed_identifier
    url = feed_updates[feed_updates["id"] == feed_identifier]["hosted_url"].iloc[0]
    GTFS_dict = parse_zipped_gtfs(url)
    # get stops from GTFS_dict
    stops = GTFS_dict["stops.txt"]
    # create stop points geodataframe from stops
    stop_points = gpd.GeoDataFrame(stops, geometry=gpd.points_from_xy(stops.stop_lon, stops.stop_lat))
    # run point in polygon check, and return a new column "in_boundary"
    stop_points["in_boundary"] = stop_points.geometry.apply(lambda x: boundary_shape.contains(x))
    # print(stop_points.columns)
    print("Distribution of stop points in boundary: ")
    print(stop_points["in_boundary"].value_counts())
    return stop_points

# %%
# create a dataframe of stops in the boundary
stops_in_boundary = pd.DataFrame()
feed_candidates = ["mdb-513-202412120015", "mdb-513-202501020055", "mdb-513-202501230024"]
for feed_identifier in feed_candidates:
    stop_points = create_and_check_stop_points(feed_identifier, feed_updates, boundary)
    stop_points = stop_points[stop_points["in_boundary"] == True]
    stops_in_boundary = pd.concat([stops_in_boundary, stop_points])
    # drop duplcates if stop_id is the same
    stops_in_boundary = stops_in_boundary.drop_duplicates(subset="stop_id")

print(stops_in_boundary.shape)
# Out:
# Parsed GTFS static feed data successfully, length:  8
# Distribution of stop points in boundary:
# in_boundary
# False    1045
# True      799
# Name: count, dtype: int64
# Parsed GTFS static feed data successfully, length:  8
# Distribution of stop points in boundary:
# in_boundary
# False    1044
# True      799
# Name: count, dtype: int64
# Parsed GTFS static feed data successfully, length:  8
# Distribution of stop points in boundary:
# in_boundary
# False    1044
# True      799
# Name: count, dtype: int64
# (799, 11)

# %%
# match speed data with stops in the boundary

# create a set of valid stop ids
valid_stop_ids = set(stops_in_boundary["stop_id"])

# CORE: Filter the data with valid stop ids within the congestion zone boundary
bus_speed_comparison_cz = bus_speed_comparison[bus_speed_comparison["stop_id"].isin(valid_stop_ids) & bus_speed_comparison["prev_stop_id"].isin(valid_stop_ids)]
bus_speed_experiment_cz = bus_speed_experiment[bus_speed_experiment["stop_id"].isin(valid_stop_ids) & bus_speed_experiment["prev_stop_id"].isin(valid_stop_ids)]

print(bus_speed_comparison_cz.shape)
print(bus_speed_experiment_cz.shape)
# Out:
# (3467, 15)
# (6708, 15)

# %% [markdown]
# ### Timezone check and conversion

# %%
# Raw timestamp:
# POSIX time (Unix epoch time) - the number of seconds elapsed since January 1, 1970, 00:00:00 UTC

def convert_to_nyc_time(df):
    eastern_tz = pytz.timezone('America/New_York')
    df['interpolated_time'] = pd.to_datetime(df['interpolated_time'])
    df['datetime_nyc'] = df['interpolated_time'].dt.tz_localize('UTC').dt.tz_convert(eastern_tz)
    return df

bus_speed_comparison_cz = convert_to_nyc_time(bus_speed_comparison_cz)
bus_speed_experiment_cz = convert_to_nyc_time(bus_speed_experiment_cz )

# %% [markdown]
# ## Data Aggregation and Visualization

# %%
# preparation

# hour: no date information retained, convert to integer
bus_speed_experiment_cz["hour"] = bus_speed_experiment_cz["datetime_nyc"].dt.floor("h").dt.hour.astype(int)
bus_speed_comparison_cz["hour"] = bus_speed_comparison_cz["datetime_nyc"].dt.floor("h").dt.hour.astype(int)

# weekday: integer representation of the day of the week
bus_speed_experiment_cz["weekday"] = bus_speed_experiment_cz["datetime_nyc"].dt.dayofweek
bus_speed_comparison_cz["weekday"] = bus_speed_comparison_cz["datetime_nyc"].dt.dayofweek

print(bus_speed_experiment_cz.iloc[0])
print(bus_speed_experiment_cz["hour"].unique())
print(bus_speed_experiment_cz["weekday"].unique())
# Out:
# trip_id                                         MQ_A5-Weekday-030500_M50_351
# shape_id                                                             M500049
# stop_sequence                                                              3
# stop_id                                                               402185
# stop_name                                                       E 49 ST/3 AV
# prev_stop_id                                                          405193
# prev_stop_name                                                  E 49 ST/2 Av
# projected_position                                               1409.476125
# prev_projected_position                                           754.684091
# segment_length                                                    654.792033
# interpolated_time                                        2025-01-08 02:02:15
# time_elapsed                                                            36.0
# ...

# %% [markdown]
# #### 1. Speed by Hour

# %%
df_experiment = bus_speed_experiment_cz.copy()
df_comparison = bus_speed_comparison_cz.copy()

# median speed, group by hour and weekday
df_experiment = df_experiment.groupby(["hour", "weekday"]).agg(
    speed_median = ("speed_mph", "median")
).reset_index()

df_comparison = df_comparison.groupby(["hour", "weekday"]).agg(
    speed_median = ("speed_mph", "median")
).reset_index()

# Generate a plot with x-axis as hour of the day and y-axis as median speed (mph)
plt.figure(figsize=(10, 6))
plt.plot(df_experiment["hour"], df_experiment["speed_median"], label="Experiment")
plt.plot(df_comparison["hour"], df_comparison["speed_median"], label="Comparison")
plt.title("Median Speed by Hour")
plt.xlabel("Hour of the Day")
plt.ylabel("Median Speed (mph)")
plt.xticks(range(0, 24))
plt.legend()
plt.grid(True)
plt.show()

# %%
df_experiment = bus_speed_experiment_cz.copy()
df_comparison = bus_speed_comparison_cz.copy()

# average speed, group by hour and weekday
df_experiment = df_experiment.groupby(["hour", "weekday"]).agg(
    total_segment_length=("segment_length", "sum"),
    total_time_elapsed=("time_elapsed", "sum")
).reset_index()
df_experiment["speed_mean"] = df_experiment["total_segment_length"] / df_experiment["total_time_elapsed"]

df_comparison = df_comparison.groupby(["hour", "weekday"]).agg(
    total_segment_length=("segment_length", "sum"),
    total_time_elapsed=("time_elapsed", "sum")
).reset_index()
df_comparison["speed_mean"] = df_comparison["total_segment_length"] / df_comparison["total_time_elapsed"]

# Generate a plot with x-axis as hour of the day and y-axis as mean speed (mph)
plt.figure(figsize=(10, 6))
plt.plot(df_experiment["hour"], df_experiment["speed_mean"], label="Experiment")
plt.plot(df_comparison["hour"], df_comparison["speed_mean"], label="Comparison")
plt.title("Average Speed by Hour")
plt.xlabel("Hour of the Day")
plt.ylabel("Mean Speed (mph)")
plt.xticks(range(0, 24))
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# #### 2. Speed by Segment and Day
#
# In NYC's congestion pricing program, peak hours for tolls are from 5 a.m. to 9 p.m. on weekdays and 9 a.m. to 9 p.m. on weekends, with tolls costing $9 for most drivers with E-ZPass, and $2.25 during overnight hours.
#
# MTA bus rush hours in Manhattan typically occur during the morning (7:00 AM - 10:00 AM) and evening (4:00 PM - 7:00 PM) on weekdays, with the Midtown area being particularly congested.

# %% [markdown]
# #### 2.1 Median Speed by Segment and Day

# %%
df_experiment = bus_speed_experiment_cz.copy()
df_comparison = bus_speed_comparison_cz.copy()

# get the segment df first
# TODO: map: date, feed identifier, url, GTFS_dict, shape, segment
# might cause some mismatch as date -> feed -> shape -> segment
url = "https://files.mobilitydatabase.org/mdb-513/mdb-513-202501020055/mdb-513-202501020055.zip"
segment_df = GTFS_shape_processor(url, 4326, 2263).process_shapes()

# median speed for each segment
# merge on (prev_stop_id, stop_id)
fig, axes = plt.subplots(1, 2, figsize=(15, 7))

# Convert segment_df to web mercator projection (EPSG:3857) required for contextily
segment_df_wm = segment_df.to_crs(epsg=3857)

# Create the experiment plot
segment_df_wm.merge(df_experiment.groupby(["prev_stop_id", "stop_id"])["speed_mph"].median().reset_index()).plot(
    column="speed_mph", 
    legend=True, 
    ax=axes[0],
    alpha=0.7,  # Make segments slightly transparent
    cmap='viridis'  # Use a nice colormap
)
axes[0].set_title("Experiment: Median Speed of the Day")
ctx.add_basemap(axes[0], source=ctx.providers.CartoDB.Positron)  # Add basemap

# Create the comparison plot
segment_df_wm.merge(df_comparison.groupby(["prev_stop_id", "stop_id"])["speed_mph"].median().reset_index()).plot(
    column="speed_mph", 
    legend=True, 
    ax=axes[1],
    alpha=0.7,  # Make segments slightly transparent
    cmap='viridis'  # Use a nice colormap
)
axes[1].set_title("Comparison: Median Speed of the Day")
ctx.add_basemap(axes[1], source=ctx.providers.CartoDB.Positron)  # Add basemap

# Remove axes
for ax in axes:
    ax.set_axis_off()

plt.tight_layout()
plt.show()
# Out:
# Parsed GTFS static feed data successfully, length:  8
# /Users/luohy/Documents/Projects/bus-observatory/gtfs-realtime-performance/.venv/lib/python3.10/site-packages/shapely/linear.py:88: RuntimeWarning: invalid value encountered in line_locate_point
#   return lib.line_locate_point(line, other)

# %%
df_experiment = bus_speed_experiment_cz.copy()
df_comparison = bus_speed_comparison_cz.copy()

# Filter out the data for morning rush hours
df_experiment = df_experiment[df_experiment["hour"].isin([7, 8, 9, 10])]
df_comparison = df_comparison[df_comparison["hour"].isin([7, 8, 9, 10])]

print(df_experiment.shape)
print(df_comparison.shape)
# Get the segment df first
url = "https://files.mobilitydatabase.org/mdb-513/mdb-513-202501020055/mdb-513-202501020055.zip"
segment_df = GTFS_shape_processor(url, 4326, 2263).process_shapes()

# Calculate median speed for each segment in both datasets
experiment_speeds = df_experiment.groupby(["prev_stop_id", "stop_id"])["speed_mph"].median().reset_index()
experiment_speeds.rename(columns={"speed_mph": "experiment_speed"}, inplace=True)

comparison_speeds = df_comparison.groupby(["prev_stop_id", "stop_id"])["speed_mph"].median().reset_index()
comparison_speeds.rename(columns={"speed_mph": "comparison_speed"}, inplace=True)

# Merge the two dataframes to calculate the difference
merged_speeds = experiment_speeds.merge(
    comparison_speeds, 
    on=["prev_stop_id", "stop_id"], 
    how="outer"
)

# Calculate the difference (experiment - comparison)
merged_speeds["speed_diff"] = merged_speeds["experiment_speed"] - merged_speeds["comparison_speed"]

# Keep only those > 0
merged_speeds = merged_speeds[merged_speeds["speed_diff"] > 0]

# Convert segment_df to web mercator projection (EPSG:3857) required for contextily
segment_df_wm = segment_df.to_crs(epsg=3857)

# Create a single plot showing the speed difference
fig, ax = plt.subplots(figsize=(12, 10))

# Plot the speed difference
speed_diff_plot = segment_df_wm.merge(merged_speeds, on=["prev_stop_id", "stop_id"]).plot(
    column="speed_diff", 
    legend=True, 
    ax=ax,
    alpha=0.7,
    cmap='Greens',  
    vmin=0,      # Adjust these min/max values as needed
    vmax=5,
    linewidth=3   # Make the line wider
)

# Add title and basemap
ax.set_title("Median Speed Difference: 2025 January vs 2024 December (mph) for Morning Rush Hours", fontsize=14)
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron)

# Remove axis
ax.set_axis_off()

plt.tight_layout()
plt.show()
# Out:
# (1639, 18)
# (936, 18)
# Parsed GTFS static feed data successfully, length:  8
# /Users/luohy/Documents/Projects/bus-observatory/gtfs-realtime-performance/.venv/lib/python3.10/site-packages/shapely/linear.py:88: RuntimeWarning: invalid value encountered in line_locate_point
#   return lib.line_locate_point(line, other)

# %% [markdown]
# #### 2.2 Average Speed by Segment and Day

# %%
df_experiment = bus_speed_experiment_cz.copy()
df_comparison = bus_speed_comparison_cz.copy()

# get the segment df first
# TODO: map: date, feed identifier, url, GTFS_dict, shape, segment
# might cause some mismatch as date -> feed -> shape -> segment
url = "https://files.mobilitydatabase.org/mdb-513/mdb-513-202501020055/mdb-513-202501020055.zip"
segment_df = GTFS_shape_processor(url, 4326, 2263).process_shapes()

# mean speed for each segment
# speed_mean = sum(segment_length) / sum(time_elapsed)
df_experiment = df_experiment.groupby(["weekday", "prev_stop_id", "stop_id"]).agg(
    total_segment_length=("segment_length", "sum"),
    total_time_elapsed=("time_elapsed", "sum")
).reset_index()
df_experiment["speed_mean"] = df_experiment["total_segment_length"] / df_experiment["total_time_elapsed"]

df_comparison = df_comparison.groupby(["weekday", "prev_stop_id", "stop_id"]).agg(
    total_segment_length=("segment_length", "sum"),
    total_time_elapsed=("time_elapsed", "sum")
).reset_index()
df_comparison["speed_mean"] = df_comparison["total_segment_length"] / df_comparison["total_time_elapsed"]

# Plot
fig, axes = plt.subplots(1, 2, figsize=(15, 7))

# Convert segment_df to web mercator projection (EPSG:3857) required for contextily
segment_df_wm = segment_df.to_crs(epsg=3857)

# Create the experiment plot
experiment_plot = segment_df_wm.merge(
    df_experiment.groupby(["prev_stop_id", "stop_id"])["speed_mean"].median().reset_index()
).plot(
    column="speed_mean", 
    legend=True, 
    ax=axes[0],
    alpha=0.7,  # Make segments slightly transparent
    cmap='viridis'  # Use a nice colormap
)
axes[0].set_title("Experiment: Average Speed of the Day")
ctx.add_basemap(axes[0], source=ctx.providers.CartoDB.Positron)  # Add basemap

# Create the comparison plot
comparison_plot = segment_df_wm.merge(
    df_comparison.groupby(["prev_stop_id", "stop_id"])["speed_mean"].median().reset_index()
).plot(
    column="speed_mean", 
    legend=True, 
    ax=axes[1],
    alpha=0.7,  # Make segments slightly transparent
    cmap='viridis'  # Use a nice colormap
)
axes[1].set_title("Comparison: Average Speed of the Day")
ctx.add_basemap(axes[1], source=ctx.providers.CartoDB.Positron)  # Add basemap

# Remove axes
for ax in axes:
    ax.set_axis_off()

plt.tight_layout()
plt.show()
# Out:
# Parsed GTFS static feed data successfully, length:  8
# /Users/luohy/Documents/Projects/bus-observatory/gtfs-realtime-performance/.venv/lib/python3.10/site-packages/shapely/linear.py:88: RuntimeWarning: invalid value encountered in line_locate_point
#   return lib.line_locate_point(line, other)

# %%
df_experiment = bus_speed_experiment_cz.copy()
df_comparison = bus_speed_comparison_cz.copy()

# Filter out the data for morning rush hours
df_experiment = df_experiment[df_experiment["hour"].isin([7, 8, 9, 10])]
df_comparison = df_comparison[df_comparison["hour"].isin([7, 8, 9, 10])]

# get the segment df first
url = "https://files.mobilitydatabase.org/mdb-513/mdb-513-202501020055/mdb-513-202501020055.zip"
segment_df = GTFS_shape_processor(url, 4326, 2263).process_shapes()
# Calculate total segment length and total time elapsed for both datasets
experiment_speeds = df_experiment.groupby(["prev_stop_id", "stop_id"]).agg(
    total_segment_length=("segment_length", "sum"),
    total_time_elapsed=("time_elapsed", "sum")
).reset_index()
experiment_speeds["experiment_speed"] = experiment_speeds["total_segment_length"] / experiment_speeds["total_time_elapsed"]

comparison_speeds = df_comparison.groupby(["prev_stop_id", "stop_id"]).agg(
    total_segment_length=("segment_length", "sum"),
    total_time_elapsed=("time_elapsed", "sum")
).reset_index()
comparison_speeds["comparison_speed"] = comparison_speeds["total_segment_length"] / comparison_speeds["total_time_elapsed"]

# Merge the two dataframes to calculate the difference
merged_speeds = experiment_speeds.merge(
    comparison_speeds, 
    on=["prev_stop_id", "stop_id"], 
    how="outer"
)

# Calculate the difference (experiment - comparison)
merged_speeds["speed_diff"] = merged_speeds["experiment_speed"] - merged_speeds["comparison_speed"]

# Keep only those > 0
merged_speeds = merged_speeds[merged_speeds["speed_diff"] > 0]

# Convert segment_df to web mercator projection (EPSG:3857) required for contextily
segment_df_wm = segment_df.to_crs(epsg=3857)

# Create a single plot showing the speed difference
fig, ax = plt.subplots(figsize=(12, 10))

# Plot the speed difference
speed_diff_plot = segment_df_wm.merge(merged_speeds, on=["prev_stop_id", "stop_id"]).plot(
    column="speed_diff", 
    legend=True, 
    ax=ax,
    alpha=0.7,
    cmap='Greens',  # Red-Blue colormap (red for negative, blue for positive)
    vmin=0,         # Adjust these min/max values as needed
    vmax=5,
    linewidth=3  # Make the line wider
)

# Add title and basemap
ax.set_title("Speed Difference: 2025 January vs 2024 December (mph) for Morning Rush Hours", fontsize=14)
ctx.add_basemap(ax, source=ctx.providers.CartoDB.Positron)

# Remove axis
ax.set_axis_off()

plt.tight_layout()
plt.show()
# Out:
# Parsed GTFS static feed data successfully, length:  8
# /Users/luohy/Documents/Projects/bus-observatory/gtfs-realtime-performance/.venv/lib/python3.10/site-packages/shapely/linear.py:88: RuntimeWarning: invalid value encountered in line_locate_point
#   return lib.line_locate_point(line, other)

# %% [markdown]
# ### Speed Change by Distance along a Trip (Skipped for now)

# %%
# project_position
# prev_projected_position
# stop_sequence: stop_sequence is a number that indicates the ordering of stops on a trip. It helps distinguish between visits to the same physical stop when a route loops back or passes the same location multiple times
# compute unique combinations of (prev_projected_position, projected_position, stop_sequence)

df_experiment = bus_speed_experiment_cz.copy()
df_comparison = bus_speed_comparison_cz.copy()

# Treat prev_projected_position and projected_position as 2 positions, and assign them the same speed
# Compute the mean speed for each position

# create a DataFrame with both positions and their corresponding speeds for experiment
positions_speeds_experiment = pd.concat([
    df_experiment[["prev_projected_position", "speed_mph"]].rename(columns={"prev_projected_position": "position"}),
    df_experiment[["projected_position", "speed_mph"]].rename(columns={"projected_position": "position"})
])

# create a DataFrame with both positions and their corresponding speeds for comparison
positions_speeds_comparison = pd.concat([
    df_comparison[["prev_projected_position", "speed_mph"]].rename(columns={"prev_projected_position": "position"}),
    df_comparison[["projected_position", "speed_mph"]].rename(columns={"projected_position": "position"})
])

# compute the mean speed for each position for experiment
mean_speeds_experiment = positions_speeds_experiment.groupby("position")["speed_mph"].mean().reset_index()

# compute the mean speed for each position for comparison
mean_speeds_comparison = positions_speeds_comparison.groupby("position")["speed_mph"].mean().reset_index()

# plot: x - position, y - speed for both experiment and comparison
plt.figure(figsize=(10, 6))
plt.plot(mean_speeds_experiment["position"], mean_speeds_experiment["speed_mph"], label="Experiment")
plt.plot(mean_speeds_comparison["position"], mean_speeds_comparison["speed_mph"], label="Comparison")
plt.title("Average Speed by Position")
plt.xlabel("Position")
plt.ylabel("Speed (mph)")
plt.legend()
plt.show()
