# %%
import os 
os.chdir("/home/canyon/Bus-Weather-Impacts")
from src.utils import *
import pandas as pd
import os
import osmnx as ox
import geopandas as gpd
import networkx as nx
from sklearn.neighbors import KDTree
import numpy as np

# %%
NYC_gtfs_rt
# Out:
#         route               timestamp    route_long direction service_date  \
# 0         B62 2023-07-05 00:06:33.000  MTA NYCT_B62         0   2023-07-04
# 1         B62 2023-07-05 00:06:49.175  MTA NYCT_B62         1   2023-07-04
# 2         B62 2023-07-05 00:06:38.000  MTA NYCT_B62         0   2023-07-04
# 3         B62 2023-07-05 00:06:54.000  MTA NYCT_B62         1   2023-07-04
# 4         B62 2023-07-05 00:06:38.000  MTA NYCT_B62         0   2023-07-04
# ...       ...                     ...           ...       ...          ...
# 1985458   S59 2023-07-05 21:53:37.000  MTA NYCT_S59         0   2023-07-05
# 1985459   S59 2023-07-05 21:53:44.000  MTA NYCT_S59         1   2023-07-05
# 1985460   S52 2023-07-05 21:53:49.000  MTA NYCT_S52         1   2023-07-05
# 1985461   S52 2023-07-05 21:53:53.000  MTA NYCT_S52         0   2023-07-05
# 1985462   S52 2023-07-05 21:53:39.000  MTA NYCT_S52         0   2023-07-05
#
#                                              trip_id gtfs_shape_id  \
# 0             MTA NYCT_GA_C3-Saturday-135100_B62_832   MTA_B620014
# 1             MTA NYCT_GA_C3-Saturday-138000_B47_435   MTA_B620010
# 2             MTA NYCT_GA_C3-Saturday-143100_B62_830   MTA_B620014
# 3             MTA NYCT_GA_C3-Saturday-138000_B47_435   MTA_B620010
# 4             MTA NYCT_GA_C3-Saturday-139100_B62_829   MTA_B620014
# ...                                              ...           ...
# 1985458   MTA NYCT_YU_C3-Weekday-SDon-129200_S59_445   MTA_S590029
# 1985459   MTA NYCT_YU_C3-Weekday-SDon-130500_S59_448   MTA_S590027
# 1985460  MTA NYCT_CA_C3-Weekday-SDon-132000_S4252_33   MTA_S520030
# 1985461  MTA NYCT_CA_C3-Weekday-SDon-127000_MISC_348   MTA_S520029
# 1985462  MTA NYCT_CA_C3-Weekday-SDon-130000_S4252_34   MTA_S520029
#
#         route_short    agency   origin_id  ... next_stop_d_along_route  \
# 0               B62  MTA NYCT  MTA_307997  ...                12573.74
# 1               B62  MTA NYCT  MTA_504413  ...                11626.34
# 2               B62  MTA NYCT  MTA_307997  ...                 2292.04
# 3               B62  MTA NYCT  MTA_504413  ...                11851.55
# 4               B62  MTA NYCT  MTA_307997  ...                12573.74
# ...             ...       ...         ...  ...                     ...
# 1985458         S59  MTA NYCT  MTA_200371  ...                 8212.47
# 1985459         S59  MTA NYCT  MTA_202744  ...                 2975.16
# 1985460         S52  MTA NYCT  MTA_202579  ...                 5367.01
# 1985461         S52  MTA NYCT  MTA_805127  ...                11665.29
# 1985462         S52  MTA NYCT  MTA_805127  ...                 5819.96
#
#         next_stop_d        lat        lon     bearing   progress_rate  \
# 0              0.00  40.749716 -73.939080   49.398705      noProgress
# 1             13.19  40.690699 -73.987760  239.275300  normalProgress
# 2             13.40  40.698032 -73.980544  271.388700  normalProgress
# 3             34.04  40.690258 -73.989378  160.804530  normalProgress
# 4             34.55  40.749456 -73.939303   49.398705      noProgress
# ...             ...        ...        ...         ...             ...
# 1985458       65.14  40.592189 -74.163603   36.528854  normalProgress
# 1985459      259.77  40.624224 -74.148980  257.554900  normalProgress
# 1985460        9.37  40.624398 -74.079497  297.645970  normalProgress
# 1985461       11.71  40.643615 -74.084289  127.860960  normalProgress
# 1985462      264.35  40.601876 -74.071476   22.750977  normalProgress
#
#             vehicle_id                                    gtfs_block_id  \
# 0        MTA NYCT_7223       MTA NYCT_GA_C3-Saturday_A_GA_75480_B62-832
# 1        MTA NYCT_9549                                             None
# 2        MTA NYCT_7236                                             None
# 3        MTA NYCT_9506                                             None
# 4        MTA NYCT_7217                                             None
# ...                ...                                              ...
# 1985458  MTA NYCT_8728   MTA NYCT_YU_C3-Weekday-SDon_E_YU_58680_S59-446
# 1985459  MTA NYCT_8186   MTA NYCT_YU_C3-Weekday-SDon_E_YU_73380_S59-448
# 1985460  MTA NYCT_7073                                             None
# 1985461  MTA NYCT_8717  MTA NYCT_CA_C3-Weekday-SDon_E_CA_64800_MISC-348
# 1985462  MTA NYCT_7064  MTA NYCT_CA_C3-Weekday-SDon_E_CA_70260_S4252-34
#
#         passenger_count progress_status
# 0                   1.0         layover
# 1                   NaN            None
# 2                   5.0            None
# 3                   NaN            None
# 4                   NaN         layover
# ...                 ...             ...
# 1985458            12.0            None
# 1985459             6.0            None
# 1985460             NaN            None
# 1985461            15.0            None
# 1985462             NaN            None
#
# [1985463 rows x 23 columns]

# %%
buses = read_parquet_from_tar_gz("https://urbantech-public.s3.amazonaws.com/DO-NOT-DELETE-BUSOBSERVATORY-PUBLIC-DATASET/one-system-day.tar.gz")

# %%
df = pd.read_parquet('https://urbantech-public.s3.amazonaws.com/pickup/dump_NYC_GTFSRT/20240108_183520_00129_ygreg_ffbd96b2-8380-4c00-adbc-536f2fcb8079')

# %%
df['vehicle.trip.start_date'].value_counts()
# Out:
# vehicle.trip.start_date
# 20231024    137765
# 20230727    131072
# 20231214    126179
# 20231113    125261
# 20231201    122015
#              ...
# 20230604     26970
# 20231029     24638
# 20230529     20535
# 20230611     20336
# 20230427     16044
# Name: count, Length: 257, dtype: int64

# %%
place = "New York City, New York, USA"
G = ox.graph_from_place(place, network_type='drive')

# Convert graph nodes to a DataFrame for KDTree
nodes = ox.graph_to_gdfs(G, edges=False).reset_index()
tree = KDTree(nodes[['y', 'x']], metric='euclidean')

# %%
# Query the KDTree for nearest node to each point
nearest_nodes = tree.query(np.array(buses[['lat', 'lon']]), k=1, return_distance=False)
buses['nearest_node'] = nearest_nodes.flatten()

# Map node IDs to OSM IDs
buses['nearest_osm_id'] = buses['nearest_node'].map(nodes['osmid'])
buses = buses.merge(nodes, left_on = "nearest_osm_id", right_on = "osmid")
buses = gpd.GeoDataFrame(buses, geometry='geometry')

# %%
buses["time_diff"] = buses.groupby("trip_id")["timestamp"].diff().dt.total_seconds()
buses = buses.query("time_diff >= 60")

# %%
buses_with_nodes = buses.sort_values(["trip_id", "timestamp"]).drop_duplicates(subset = ["trip_id", "nearest_osm_id"],  keep = "first").to_crs(2263)
buses_with_nodes = buses_with_nodes[["route", "timestamp", "trip_id", "osmid", "vehicle_id",  "geometry"]]
buses_with_nodes["prev_osmid"] = buses_with_nodes.groupby("trip_id")["osmid"].shift()

# %%
def compute_distance(row, graph):
    try:
        return nx.shortest_path_length(graph, row['prev_osmid'], row['osmid'], weight='length')
    except nx.NetworkXNoPath:
        return float('nan')
    
def compute_euclid_dists(node_pairs, nodes_points):
    node_pairs = node_pairs.merge(nodes_points, left_on = "osmid", right_on = "osmid", how = "left").merge(nodes_points, right_on = "osmid", left_on = "prev_osmid", how = "left", suffixes = ["curr", "prev"])
    node_pairs["x_diff_sq"] = (node_pairs["xcurr"] - node_pairs["xprev"])**2
    node_pairs["y_diff_sq"] = (node_pairs["ycurr"] - node_pairs["yprev"])**2

    return (node_pairs["x_diff_sq"] + node_pairs["y_diff_sq"]) ** (1/2)

nodes_points = nodes.to_crs(2263)
nodes_points["x"] = nodes_points.geometry.x
nodes_points["y"] = nodes_points.geometry.y
nodes_points = nodes_points[["osmid", "x", "y"]]

unqiue_node_pairs = buses_with_nodes[["osmid", "prev_osmid"]].dropna().drop_duplicates().astype("Int64").reset_index()
unqiue_node_pairs["distance_meters_osm"] = unqiue_node_pairs.apply(compute_distance, graph=G, axis=1)
unqiue_node_pairs["distance_meters_euclid"] = compute_euclid_dists(unqiue_node_pairs, nodes_points) / 3.28

unqiue_node_pairs.to_parquet("data/node_pairs.parquet")

unique_node_pairs = pd.read_parquet("data/node_pairs.parquet")
buses_with_nodes = buses_with_nodes.merge(unique_node_pairs, how = "left")
buses_with_nodes["osmid"] = buses_with_nodes["osmid"].astype(str)
buses_with_nodes["prev_osmid"] = buses_with_nodes["prev_osmid"].astype("Int64").astype(str)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 20
#      17 nodes_points = nodes_points[["osmid", "x", "y"]]
#      19 unqiue_node_pairs = buses_with_nodes[["osmid", "prev_osmid"]].dropna().drop_duplicates().astype("Int64").reset_index()
# ---> 20 unqiue_node_pairs["distance_meters_osm"] = unqiue_node_pairs.apply(compute_distance, graph=G, axis=1)
#      21 unqiue_node_pairs["distance_meters_euclid"] = compute_euclid_dists(unqiue_node_pairs, nodes_points) / 3.28
#      23 unqiue_node_pairs.to_parquet("data/node_pairs.parquet")
#
# File ~/.local/share/virtualenvs/TOP-Sprint-lAvM2-mU/lib/python3.9/site-packages/pandas/core/frame.py:10347, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10333 from pandas.core.apply import frame_apply
#   10335 op = frame_apply(
#   10336     self,
#   10337     func=func,
#    (...)
#   10345     kwargs=kwargs,
#   10346 )
# > 10347 return op.apply().__finalize__(self, method="apply")
#
# File ~/.local/share/virtualenvs/TOP-Sprint-lAvM2-mU/lib/python3.9/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/.local/share/virtualenvs/TOP-Sprint-lAvM2-mU/lib/python3.9/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/.local/share/virtualenvs/TOP-Sprint-lAvM2-mU/lib/python3.9/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[10], line 3, in compute_distance(row, graph)
#       1 def compute_distance(row, graph):
#       2     try:
# ----> 3         return nx.shortest_path_length(graph, row['prev_osmid'], row['osmid'], weight='length')
#       4     except nx.NetworkXNoPath:
#       5         return float('nan')
#
# File ~/.local/share/virtualenvs/TOP-Sprint-lAvM2-mU/lib/python3.9/site-packages/networkx/utils/backends.py:412, in _dispatch.__call__(self, backend, *args, **kwargs)
#     409 def __call__(self, /, *args, backend=None, **kwargs):
#     410     if not backends:
#     411         # Fast path if no backends are installed
# --> 412         return self.orig_func(*args, **kwargs)
#     414     # Use `backend_name` in this function instead of `backend`
#     415     backend_name = backend
#
# File ~/.local/share/virtualenvs/TOP-Sprint-lAvM2-mU/lib/python3.9/site-packages/networkx/algorithms/shortest_paths/generic.py:319, in shortest_path_length(G, source, target, weight, method)
#     317     paths = len(p) - 1
#     318 elif method == "dijkstra":
# --> 319     paths = nx.dijkstra_path_length(G, source, target, weight)
#     320 else:  # method == 'bellman-ford':
#     321     paths = nx.bellman_ford_path_length(G, source, target, weight)
#
# File ~/.local/share/virtualenvs/TOP-Sprint-lAvM2-mU/lib/python3.9/site-packages/networkx/utils/backends.py:412, in _dispatch.__call__(self, backend, *args, **kwargs)
#     409 def __call__(self, /, *args, backend=None, **kwargs):
#     410     if not backends:
#     411         # Fast path if no backends are installed
# --> 412         return self.orig_func(*args, **kwargs)
#     414     # Use `backend_name` in this function instead of `backend`
#     415     backend_name = backend
#
# File ~/.local/share/virtualenvs/TOP-Sprint-lAvM2-mU/lib/python3.9/site-packages/networkx/algorithms/shortest_paths/weighted.py:245, in dijkstra_path_length(G, source, target, weight)
#     243     return 0
#     244 weight = _weight_function(G, weight)
# --> 245 length = _dijkstra(G, source, weight, target=target)
#     246 try:
#     247     return length[target]
#
# File ~/.local/share/virtualenvs/TOP-Sprint-lAvM2-mU/lib/python3.9/site-packages/networkx/algorithms/shortest_paths/weighted.py:776, in _dijkstra(G, source, weight, pred, paths, cutoff, target)
#     767 def _dijkstra(G, source, weight, pred=None, paths=None, cutoff=None, target=None):
#     768     """Uses Dijkstra's algorithm to find shortest weighted paths from a
#     769     single source.
#     770
#    (...)
#     774
#     775     """
# --> 776     return _dijkstra_multisource(
#     777         G, [source], weight, pred=pred, paths=paths, cutoff=cutoff, target=target
#     778     )
#
# File ~/.local/share/virtualenvs/TOP-Sprint-lAvM2-mU/lib/python3.9/site-packages/networkx/algorithms/shortest_paths/weighted.py:870, in _dijkstra_multisource(G, sources, weight, pred, paths, cutoff, target)
#     868 elif u not in seen or vu_dist < seen[u]:
#     869     seen[u] = vu_dist
# --> 870     push(fringe, (vu_dist, next(c), u))
#     871     if paths is not None:
#     872         paths[u] = paths[v] + [u]
#
# KeyboardInterrupt:

# %%
buses_with_nodes["time_diff_seconds"] = buses_with_nodes.groupby("trip_id")["timestamp"].diff().dt.total_seconds()
buses_with_nodes["speed_mph_osm"] =  (buses_with_nodes["distance_meters_osm"] / 1609) / (buses_with_nodes["time_diff_seconds"] / 3600)
buses_with_nodes["speed_mph_euclid"] =  (buses_with_nodes["distance_meters_euclid"] / 1609) / (buses_with_nodes["time_diff_seconds"] / 3600)

# %%
unqiue_node_pairs
# Out:
#           index       osmid  prev_osmid  distance_meters_osm  \
# 0       1669752    42971120    42952118              206.579
# 1       1670341    42971112    42971120              410.265
# 2       1670923    42962132    42971112              570.504
# 3       1670013    42965719    42955712              483.900
# 4       1670584    42965724    42965719              173.052
# ...         ...         ...         ...                  ...
# 244669  1529217    42961868    42978240              430.090
# 244670  1858971    43003233    42946631             1159.058
# 244671  1859741    42995428    43003233              530.619
# 244672  1593434    42978095    42973998              963.011
# 244673  1595263  8264070984    42978105              797.705
#
#         distance_meters_euclid
# 0                   206.356691
# 1                   409.824293
# 2                   401.598082
# 3                   379.680800
# 4                   172.722905
# ...                        ...
# 244669              429.156779
# 244670              749.803972
# 244671              530.039548
# 244672              963.330683
# 244673              788.538731
#
# [244674 rows x 5 columns]

# %%
compute_euclid_dists(unqiue_node_pairs, nodes_points) / 3.28
# Out:
# 0         206.356691
# 1         409.824293
# 2         401.598082
# 3         379.680800
# 4         172.722905
#              ...
# 244669    429.156779
# 244670    749.803972
# 244671    530.039548
# 244672    963.330683
# 244673    788.538731
# Length: 244674, dtype: float64

# %%
nodes.query("osmid == 42949762 | osmid == 598367717")
# Out:
#            osmid          y          x  ref highway  street_count  \
# 34130   42949762  40.602807 -74.057823  NaN    stop             5
# 44155  598367717  40.601605 -74.062733  NaN     NaN             3
#
#                          geometry
# 34130  POINT (-74.05782 40.60281)
# 44155  POINT (-74.06273 40.60160)

# %%
buses_with_nodes.query("speed_mph_osm > 100")
# Out:
#          route           timestamp  \
# 46       SIM3C 2023-07-05 00:06:44
# 147     SIM33C 2023-07-05 00:19:47
# 153     SIM33C 2023-07-05 00:26:56
# 154     SIM33C 2023-07-05 00:27:57
# 314      SIM3C 2023-07-05 00:42:31
# ...        ...                 ...
# 928370     S61 2023-07-05 23:40:46
# 928402   SIM1C 2023-07-05 23:52:02
# 928403   SIM1C 2023-07-05 23:53:33
# 928409   SIM1C 2023-07-05 23:59:39
# 928515     S62 2023-07-05 23:55:35
#
#                                              trip_id       osmid  \
# 46           MTA NYCT_CA_C3-Saturday-140500_MISC_360    42949767
# 147          MTA NYCT_CA_C3-Saturday-142000_MISC_369   598229486
# 153          MTA NYCT_CA_C3-Saturday-142000_MISC_369   448096469
# 154          MTA NYCT_CA_C3-Saturday-142000_MISC_369    42949767
# 314          MTA NYCT_CA_C3-Saturday-143500_MISC_386    42949767
# ...                                              ...         ...
# 928370  MTA NYCT_YU_C3-Weekday-SDon-139500_S6191_470    42964909
# 928402   MTA NYCT_YU_C3-Weekday-SDon-139800_SIM1_570    42444353
# 928403   MTA NYCT_YU_C3-Weekday-SDon-139800_SIM1_570  5487759985
# 928409   MTA NYCT_YU_C3-Weekday-SDon-139800_SIM1_570  5882645228
# 928515  MTA NYCT_YU_C3-Weekday-SDon-141000_S6292_491  1934649760
#
#            vehicle_id                       geometry  prev_osmid      index  \
# 46      MTA NYCT_2502  POINT (968884.407 159556.101)   598365323  1670618.0
# 147     MTA NYCT_2651  POINT (982625.847 187538.268)   607911351   603418.0
# 153     MTA NYCT_2651  POINT (974352.575 161675.277)    42466639   332780.0
# 154     MTA NYCT_2651  POINT (968884.407 159556.101)   448096469   333256.0
# 314     MTA NYCT_2573  POINT (968884.407 159556.101)    94436414   400445.0
# ...               ...                            ...         ...        ...
# 928370  MTA NYCT_8577  POINT (955960.661 164247.615)    42965730  1455917.0
# 928402  MTA NYCT_2560  POINT (980246.671 195458.518)    42478292  1859648.0
# 928403  MTA NYCT_2560  POINT (982755.693 189136.644)    42444353  1642641.0
# 928409  MTA NYCT_2560  POINT (979506.853 168674.767)   598322078  1595297.0
# 928515  MTA NYCT_8596  POINT (942625.835 161364.994)  5490183367  1592820.0
#
#         distance_meters_osm  distance_meters_euclid  time_diff_seconds  \
# 46                 4389.665             2117.366379               60.0
# 147                5516.712             2338.684021              122.0
# 153                7412.139             1188.759669               61.0
# 154                6622.814             1787.941903               61.0
# 314                5060.799             2028.482525               61.0
# ...                     ...                     ...                ...
# 928370             3320.777             3145.714701               51.0
# 928402             4896.660             3599.093973               67.0
# 928403             5684.558             2073.647837               91.0
# 928409             4216.049             1349.022194               61.0
# 928515             3058.480              192.994980               61.0
#
#         speed_mph_osm  speed_mph_euclid
# 46         163.691672         78.957105
# 147        101.173538         42.890210
# 153        271.869305         43.602429
# 154        242.917711         65.579790
# 314        185.624677         74.402562
# ...               ...               ...
# 928370     145.685387        138.005251
# 928402     163.520273        120.189033
# 928403     139.766074         50.984723
# 928409     154.640153         49.480686
# 928515     112.181764          7.078849
#
# [6238 rows x 13 columns]

# %%
buses_with_nodes['distance_diff_feet'] = buses_with_nodes.groupby('trip_id').apply(calculate_distances).reset_index(level=0, drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 buses_with_nodes['distance_diff_feet'] = buses_with_nodes.groupby('trip_id').apply(calculate_distances).reset_index(level=0, drop=True)
#
# NameError: name 'calculate_distances' is not defined

# %%
buses.query("route == 'M96'").plot()
# Out:
# <Axes: >

# %%
path_nodes = nx.shortest_path(G, 598367717, 42949762)

# %%
import contextily as ctx
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 10))
nodes.query("osmid.isin(@path_nodes)").to_crs(3857).plot(ax = ax)

ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 import matplotlib.pyplot as plt
#       4 fig, ax = plt.subplots(figsize=(10, 10))
# ----> 5 nodes.query("osmid.isin(@path_nodes)").to_crs(3857).plot(ax = ax)
#       7 ctx.add_basemap(ax, source=ctx.providers.OpenStreetMap.Mapnik)
#       9 plt.show()
#
# NameError: name 'nodes' is not defined
